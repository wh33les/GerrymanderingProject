# %%
from dbfread import DBF
for record in DBF("data/Indiana-shapefiles-and-files/Indiana.dbf"):
    print(record)
# Out:
# OrderedDict([('SEND', '043'), ('CD', '06'), ('TOTPOP', 986.0), ('NH_WHITE', 925.0), ('NH_BLACK', 20.0), ('NH_AMIN', 7.0), ('NH_ASIAN', 12.0), ('NH_NHPI', 0.0), ('NH_OTHER', 1.0), ('NH_2MORE', 8.0), ('HISP', 13.0), ('H_WHITE', 4.0), ('H_BLACK', 0.0), ('H_AMIN', 0.0), ('H_NHPI', 0.0), ('H_OTHER', 7.0), ('H_2MORE', 2.0), ('VAP', 767.0), ('HVAP', 8.0), ('WVAP', 729.0), ('BVAP', 16.0), ('AMINVAP', 3.0), ('ASIANVAP', 11.0), ('NHPIVAP', 0.0), ('OTHERVAP', 0.0), ('2MOREVAP', 0.0), ('PRECINCT', 'CLAY 3500'), ('STATE', 'Indiana'), ('STATEFP', '18'), ('COUNTYFP', '005'), ('PRES16D', 108), ('PRES16R', 332), ('SEN16R', 276), ('SEN16D', 142), ('SEN16L', 34), ('AG16D', 106), ('AG16R', 335), ('GOV16D', 150), ('GOV16R', 289), ('HDIST', '057'), ('H_ASIAN', 0)])
# ...

# %%
table = DBF("data/Indiana-shapefiles-and-files/Indiana.dbf", load = True)
print(table.records)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
